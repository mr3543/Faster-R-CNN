# %%
###### First remember to switch runtime type to GPU
###### Runtime -> Change Runtime Type -> Hardware Accelerator -> GPU

# mount Google drive - ckpt files will be saved to Google drive
# to protect against data loss during a disconnection with Colab

from google.colab import drive
drive.mount('/content/gdrive')

# %%
# clone gh repo

# !git clone https://github.com/mr3543/Faster-R-CNN ./gdrive/'My Drive'/Faster-R-CNN

# %%
# make ckpt and results dirs

! mkdir -p ./gdrive/'My Drive'/Faster-R-CNN/model/base_model/web
! mkdir -p ./gdrive/'My Drive'/Faster-R-CNN/model/rpn/rpn_network
! mkdir -p ./gdrive/'My Drive'/Faster-R-CNN/model/rpn/rpn_training
! mkdir -p ./gdrive/'My Drive'/Faster-R-CNN/model/rcnn/rcnn_network
! mkdir -p ./gdrive/'My Drive'/Faster-R-CNN/model/rcnn/rcnn_training
! mkdir -p ./gdrive/'My Drive'/Faster-R-CNN/model/rcnn/rcnn_network_pt
! mkdir -p ./gdrive/'My Drive'/Faster-R-CNN/results

# %%
# download training image data

# !mkdir image_data
# !wget http://images.cocodataset.org/zips/train2017.zip
# !unzip -q train2017.zip -d ./image_data
# !rm train2017.zip

# %%
# download testing image data

# !wget http://images.cocodataset.org/zips/test2017.zip
# !unzip -q test2017.zip -d ./image_data
# !rm test2017.zip

# %%
# download val image data

# !wget http://images.cocodataset.org/zips/val2017.zip
# !unzip -q val2017.zip -d ./image_data
# !rm val2017.zip

# %%
# download annotations 

# !wget http://images.cocodataset.org/annotations/annotations_trainval2017.zip
# !unzip -q annotations_trainval2017.zip -d ./image_data
# !rm annotations_trainval2017.zip

# %%
# download vgg16 pre trained weights

# !wget -v http://download.tensorflow.org/models/vgg_16_2016_08_28.tar.gz
# !tar -xzvf vgg_16_2016_08_28.tar.gz -C ./gdrive/'My Drive'/Faster-R-CNN/model/base_model/web
# !rm vgg_16_2016_08_28.tar.gz

# %%
# Run Tensorboard
LOG_DIR = './gdrive/\'My Drive\'/Faster-R-CNN/graphs'
get_ipython().system_raw(
    'tensorboard --logdir {} --host 0.0.0.0 --port 6006 &'
    .format(LOG_DIR))

# %%
# Download and unzip ngrok
! wget https://bin.equinox.io/c/4VmDzA7iaHb/ngrok-stable-linux-amd64.zip
! unzip ngrok-stable-linux-amd64.zip
! rm ngrok-stable-linux-amd64.zip

# %%
# Launch the ngrok background process
get_ipython().system_raw('./ngrok http 6006 &')

# %%
# Get the public URL
! curl -s http://localhost:4040/api/tunnels | python3 -c \
    "import sys, json; print(json.load(sys.stdin)['tunnels'][0]['public_url'])"

# %%
# train model 

# !python ./gdrive/'My Drive'/Faster-R-CNN/train_model.py

# %%
# evaluatate on coco val set

# !python ./gdrive/'My Drive'/Faster-R-CNN/eval.py
